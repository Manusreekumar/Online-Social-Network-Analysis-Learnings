# %%
from collections import Counter, defaultdict
import math
import numpy as np
import os
import pandas as pd
import re
from scipy.sparse import csr_matrix
import urllib.request
import zipfile

def download_data():
    """ DONE. Download and unzip data.
    """
    url = 'https://www.dropbox.com/s/h9ubx22ftdkyvd5/ml-latest-small.zip?dl=1'
    urllib.request.urlretrieve(url, 'ml-latest-small.zip')
    zfile = zipfile.ZipFile('ml-latest-small.zip')
    zfile.extractall()
    zfile.close()


def tokenize_string(my_string):
    """ DONE. You should use this in your tokenize function.
    """
    return re.findall('[\w\-]+', my_string.lower())

# %%
download_data()
path = 'ml-latest-small'
ratings = pd.read_csv(path + os.path.sep + 'ratings.csv')
movies = pd.read_csv(path + os.path.sep + 'movies.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movies.sort_values('title').head(100)
# Out:
#       movieId                                              title  \
# 6647    51372                   "Great Performances" Cats (1998)
# 7460    74486                                       $9.99 (2008)
# 8169    97757            'Hellboy': The Seeds of Creation (2004)
# 7280    70121                    'Neath the Arizona Skies (1934)
# 5821    26564                             'Round Midnight (1986)
# 5938    27751                                'Salem's Lot (2004)
# 643       779                          'Til There Was You (1997)
# 1632     2072                                 'burbs, The (1989)
# 2504     3112                               'night Mother (1986)
# 7269    69757                        (500) Days of Summer (2009)
# 5351     8169                     *batteries not included (1987)
# 4720     6600                            ...And God Spoke (1993)
# 2726     3420                      ...And Justice for All (1979)
# 713       889                                  1-900 (06) (1994)
# 4744     6658                                          10 (1979)
# 8980   140745                                10 Attitudes (2001)
# 9068   152077                         10 Cloverfield Lane (2016)
# 6575    49284                            10 Items or Less (2006)
# 2063     2572                  10 Things I Hate About You (1999)
# 8194    98230                                    10 Years (2011)
# 6900    58293                                   10,000 BC (2008)
# 5175     7541                                   100 Girls (2000)
# 6971    59834                                  100 Rifles (1969)
# 1108     1367                              101 Dalmatians (1996)
# 1645     2085  101 Dalmatians (One Hundred and One Dalmatians...
# 4594     6344               101 Reykjavik (101 Reykjavík) (2000)
# 3195     3991                              102 Dalmatians (2000)
# 5894    27251                           10th Kingdom, The (2000)
# 5233     7789                     11'09"01 - September 11 (2002)
# 5924    27674                                       11:14 (2003)
# ...       ...                                                ...
# 6693    52767                                       21 Up (1977)
# 8606   112138                              22 Jump Street (2014)
# 6421    45172      23 (23 - Nichts ist so wie es scheint) (1998)
# 4174     5508                        24 Hour Party People (2002)
# 1989     2486                          24 Hour Woman, The (1998)
# 7563    78729                              24: Redemption (2008)
# 6137    33380                                    25 Watts (2001)
# 4396     5954                                   25th Hour (2002)
# 6866    56949                                  27 Dresses (2008)
# 2822     3534                                     28 Days (2000)
# 4671     6502                               28 Days Later (2002)
# 5178     7566                                       28 Up (1985)
# 6702    53000                              28 Weeks Later (2007)
# 8982   140749                                29th and Gay (2005)
# 6166    33896  3 Extremes (Three... Extremes) (Saam gaang yi)...
# 7442    73881                                    3 Idiots (2009)
# 3721     4748                                    3 Ninjas (1992)
# 3722     4749                          3 Ninjas Kick Back (1994)
# 3723     4750                         3 Ninjas Knuckle Up (1995)
# 1371     1739        3 Ninjas: High Noon On Mega Mountain (1998)
# 5375     8261                       3 Women (Three Women) (1977)
# 7333    71404                   3 Worlds of Gulliver, The (1960)
# 8986   140757                               3-Day Weekend (2008)
# 5990    30803                            3-Iron (Bin-jip) (2004)
# 6798    55282                            30 Days of Night (2007)
# 7859    88812                          30 Minutes or Less (2011)
# 4037     5271                            30 Years to Life (2001)
# 6654    51662                                         300 (2007)
# 3316     4159                     3000 Miles to Graceland (2001)
# 8539   109673                      300: Rise of an Empire (2014)
#
#                                            genres
# 6647                                      Musical
# 7460                                    Animation
# 8169  Action|Adventure|Comedy|Documentary|Fantasy
# 7280                                      Western
# 5821                                Drama|Musical
# 5938                Drama|Horror|Mystery|Thriller
# 643                                 Drama|Romance
# 1632                                       Comedy
# 2504                                        Drama
# 7269                         Comedy|Drama|Romance
# 5351               Children|Comedy|Fantasy|Sci-Fi
# 4720                                       Comedy
# 2726                               Drama|Thriller
# 713                                 Drama|Romance
# 4744                               Comedy|Romance
# 8980                         Comedy|Drama|Romance
# 9068                                     Thriller
# 6575                         Comedy|Drama|Romance
# 2063                               Comedy|Romance
# 8194                         Comedy|Drama|Romance
# 6900                   Adventure|Romance|Thriller
# 5175                               Comedy|Romance
# 6971                        Adventure|War|Western
# 1108                    Adventure|Children|Comedy
# 1645                 Adventure|Animation|Children
# 4594                         Comedy|Drama|Romance
# 3195                              Children|Comedy
# 5894                     Adventure|Comedy|Fantasy
# 5233                                        Drama
# 5924          Comedy|Crime|Drama|Mystery|Thriller
# ...                                           ...
# 6693                                  Documentary
# 8606                          Action|Comedy|Crime
# 6421                               Drama|Thriller
# 4174                         Comedy|Drama|Musical
# 1989                                 Comedy|Drama
# 7563        Action|Adventure|Crime|Drama|Thriller
# 6137                                 Comedy|Drama
# 4396                                  Crime|Drama
# 6866                               Comedy|Romance
# 2822                                        Drama
# 4671                         Action|Horror|Sci-Fi
# 5178                                  Documentary
# 6702                       Horror|Sci-Fi|Thriller
# 8982                                       Comedy
# 6166                                       Horror
# 7442                         Comedy|Drama|Romance
# 3721                       Action|Children|Comedy
# 3722                       Action|Children|Comedy
# 3723                              Action|Children
# 1371                       Action|Children|Comedy
# 5375                                        Drama
# 7333                            Adventure|Fantasy
# 8986                                        Drama
# 5990                                Drama|Romance
# 6798                              Horror|Thriller
# 7859                          Action|Comedy|Crime
# 4037                         Comedy|Drama|Romance
# 6654                      Action|Fantasy|War|IMAX
# 3316                              Action|Thriller
# 8539                        Action|Drama|War|IMAX
#
# [100 rows x 3 columns]

# %%
len(ratings)
# Out:
# 100004

# %%
len(movies)
# Out:
# 9125

# %%
def tokenize(movies):
    """
    Append a new column to the movies DataFrame with header 'tokens'.
    This will contain a list of strings, one per token, extracted
    from the 'genre' field of each movie. Use the tokenize_string method above.

    Note: you may modify the movies parameter directly; no need to make
    a new copy.
    Params:
      movies...The movies DataFrame
    Returns:
      The movies DataFrame, augmented to include a new column called 'tokens'.

    >>> movies = pd.DataFrame([[123, 'Horror|Romance'], [456, 'Sci-Fi']], columns=['movieId', 'genres'])
    >>> movies = tokenize(movies)
    >>> movies['tokens'].tolist()
    [['horror', 'romance'], ['sci-fi']]
    """
    ###TODO
    movies['tokens'] = movies['genres'].apply(lambda x: tokenize_string(x))
    return movies

# %%
movies = tokenize(movies)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                               tokens
# 0  [adventure, animation, children, comedy, fantasy]
# 1                     [adventure, children, fantasy]
# 2                                  [comedy, romance]
# 3                           [comedy, drama, romance]
# 4                                           [comedy]

# %%
def featurize(movies):
    """
    Append a new column to the movies DataFrame with header 'features'.
    Each row will contain a csr_matrix of shape (1, num_features). Each
    entry in this matrix will contain the tf-idf value of the term, as
    defined in class:
    tfidf(i, d) := tf(i, d) / max_k tf(k, d) * log10(N/df(i))
    where:
    i is a term
    d is a document (movie)
    tf(i, d) is the frequency of term i in document d
    max_k tf(k, d) is the maximum frequency of any term in document d
    N is the number of documents (movies)
    df(i) is the number of unique documents containing term i

    Params:
      movies...The movies DataFrame
    Returns:
      A tuple containing:
      - The movies DataFrame, which has been modified to include a column named 'features'.
      - The vocab, a dict from term to int. Make sure the vocab is sorted alphabetically as in a2 (e.g., {'aardvark': 0, 'boy': 1, ...})
    """
    ###TODO
    
    vocab = defaultdict(lambda:len(vocab))
    tokens_list = []
    #Created the vocabulary
    for tokens in movies['tokens']:
        tokens_list += tokens
    for tokens in sorted(tokens_list):
        vocab[tokens]
    N = len(movies)
    df = defaultdict(int)
    #We need to create a dictionary for each term with frequency
    for term in vocab.keys():
        for tokens in movies['tokens']:
            if term in tokens:
                df[term] += 1
    #freq of term i in document d
    tf = defaultdict(lambda:Counter())
    for i, tokens in enumerate(movies['tokens']):
        tf[i].update(tokens)
    
    features = []
    for i, tokens in enumerate(movies['tokens']):
        feature_array = np.zeros(shape = (1, len(vocab)))
        for token in tokens:
            #print(token)
            feature_array[0, vocab[token]] = tf[i][token] / tf[i].most_common(1)[0][1] * math.log10(N / df[token])
        features.append(csr_matrix(feature_array))
    movies['features'] = features
    return movies , df

# %%
movies_example = movies.loc[:10]

# %%
movies_example
# Out:
#     movieId                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
# 5         6                         Heat (1995)
# 6         7                      Sabrina (1995)
# 7         8                 Tom and Huck (1995)
# 8         9                 Sudden Death (1995)
# 9        10                    GoldenEye (1995)
# 10       11      American President, The (1995)
#
#                                          genres  \
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# 4                                        Comedy
# 5                         Action|Crime|Thriller
# 6                                Comedy|Romance
# 7                            Adventure|Children
# 8                                        Action
# 9                     Action|Adventure|Thriller
# 10                         Comedy|Drama|Romance
#
#                                                tokens
# 0   [adventure, animation, children, comedy, fantasy]
# 1                      [adventure, children, fantasy]
# 2                                   [comedy, romance]
# 3                            [comedy, drama, romance]
# 4                                            [comedy]
# 5                           [action, crime, thriller]
# 6                                   [comedy, romance]
# 7                               [adventure, children]
# 8                                            [action]
# 9                       [action, adventure, thriller]
# 10                           [comedy, drama, romance]

# %%
movies_example_V1 , df= featurize(movies_example)
# Out:
# C:\Users\manu sreekumar\Anaconda3\lib\site-packages\ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
movies_example_V1['features'][0].toarray()
# Out:
# array([[0.        , 0.43933269, 1.04139269, 0.56427143, 0.26324143,
#         0.        , 0.        , 0.74036269, 0.        , 0.        ]])

# %%
sorted(df.items(), key = lambda x : x[1])
# Out:
# [('animation', 1),
#  ('crime', 1),
#  ('drama', 2),
#  ('fantasy', 2),
#  ('thriller', 2),
#  ('action', 3),
#  ('children', 3),
#  ('adventure', 4),
#  ('romance', 4),
#  ('comedy', 6)]

# %%
vocab
# Out:
# defaultdict(<function __main__.featurize.<locals>.<lambda>>,
#             {'action': 0,
#              'adventure': 1,
#              'animation': 2,
#              'children': 3,
#              'comedy': 4,
#              'crime': 5,
#              'drama': 6,
#              'fantasy': 7,
#              'romance': 8,
#              'thriller': 9})
